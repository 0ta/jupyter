# %%
import numpy as np
import numpy.random as random
import scipy as sp
import pandas as pd
from pandas import Series, DataFrame

import matplotlib.pyplot as plt
import matplotlib as mpl
import seaborn as sns
# %matplotlib inline

# %precision 3

student_data_math = pd.read_csv("./data/student/student-mat.csv", ";")
print(student_data_math.shape)
#print(student_data_math)
#print(type(student_data_math))

#student_data_math.head()
#student_data_math.groupby('sex')["age"].mean()
#student_data_math.groupby('sex')["age"].median()
#student_data_math.age.mode()

"""
plt.hist(student_data_math.absences)
plt.ylabel("count")
plt.xlabel("absences")
plt.grid(True)
"""

"""
print("平均値：", student_data_math.absences.mean())
print("中央値：", student_data_math.absences.median())
print("最頻値：", student_data_math.absences.mode())
print(student_data_math.absences.var())
print(student_data_math.absences.std())
"""

plt.plot(student_data_math.G1,student_data_math.G3, 'o')
plt.ylabel("G3 grade")
plt.xlabel("G1 grade")
plt.grid(True)

#print(student_data_math)
#print(student_data_math[student_data_math.G1 == 0])
#print(student_data_math[student_data_math.G1 >= 0].loc[:,['G1','G3']])
# Out:
# (395, 33)

# %%
sns.pairplot(student_data_math[["Dalc","Walc","G1","G3"]])
plt.grid(True)

# %%
from sklearn import linear_model

# 線形回帰のインスタンスを生成
clf = linear_model.LinearRegression()
X = student_data_math.loc[:, ['G1']].values
Y = student_data_math['G3'].values
# 予測モデルを計算、ここでa,bを算出
clf.fit(X, Y)
# 回帰係数
print("回帰係数:", clf.coef_)
# 切片 
print("切片:", clf.intercept_)
# Out:
# 回帰係数: [1.106]
# 切片: -1.6528038288004616

# %%
# 先ほどと同じ散布図
plt.scatter(X, Y)
plt.xlabel("G1 grade")
plt.ylabel("G3 grade")

# その上に線形回帰直線を引く
plt.plot(X, clf.predict(X))
plt.grid(True)
